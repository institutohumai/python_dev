# %% [markdown]
# Tenes una lista de videos en tu servidor que deseas convertir a formato mp3. Además, después de convertir cada video, necesitas enviar un correo electrónico al usuario para informarle de la conversión realizada.
#
# La estructura de datos en tu servidor es asi:
#
# ```python
# info_videos = [
#     {
#         "video": "top_10_goles_messi.mp4",
#         "mail": "mail1@email.com",
#     },
#     {
#         "video": "caidas_graciosas_2023.mp4",
#         "mail": "mail_prueba@email.com",
#     },
#     {
#         "video": "tutorial_python_basico.mp4",
#         "mail": "usuario_python@email.com",
#     },
#     {
#         "video": "viaje_espacial_turismo.mp4",
#         "mail": "entusiasta_espacio@email.com",
#     },
#     {
#         "video": "documental_historia_arte.mp4",
#         "mail": "arte_historia@email.com",
#     },
#     {
#         "video": "ejercicios_yoga_principiantes.mp4",
#         "mail": "yoga_novato@email.com",
#     },
#     {
#         "video": "recetas_saludables_faciles.mp4",
#         "mail": "cocinero_saludable@email.com",
#     },
#     {
#         "video": "economia_basica_para_novatos.mp4",
#         "mail": "novato_economia@email.com",
#     },
#     {
#         "video": "aprendiendo_ajedrez_desde_cero.mp4",
#         "mail": "ajedrez_novato@email.com",
#     },
#     {
#         "video": "meditacion_guiada_30_minutos.mp4",
#         "mail": "meditacion_practicante@email.com",
#     },
#     {
#         "video": "tutorial_jardineria_basico.mp4",
#         "mail": "jardinero_principiante@email.com",
#     },
#     {
#         "video": "clases_de_frances_intermedio.mp4",
#         "mail": "aprendiz_frances@email.com",
#     }
# ]
#
# ```
#
# Tal como el ejemplo mostrado en clase deberas usar esta estructura para llenar el queue.
#
# Se especifica lo siguiente:
# - Crear 4 procesos:
#     - 1 de `enviar_video`
#     - 2 de `convertir_mp3`
#     - 1 de `enviar_mail`.
#
# - Crear 2 queues:
#     - 1 en donde `enviar_video` publicara y los 2 procesos de `convertir_mp3` la consumiran.
#     - 1 en donde `convertir_mp3` publicara y donde `enviar_mail` consumira.
#
#
#
# El programa en general lucira asi:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import multiprocessing as mp
import time


def enviar_video(info_videos, queue):
    ...


def convertir_a_mp3(queue):
    time.sleep(5) # este tiempo representa lo que tarda en convertirse
    ...


def enviar_mail(queue):
    time.sleep(1) # este tiempo representa lo que tarda en enviarse el mail
    ...



info_videos = [
    {
        "video": "top_10_goles_messi.mp4",
        "mail": "mail1@email.com",
    },
    {
        "video": "caidas_graciosas_2023.mp4",
        "mail": "mail_prueba@email.com",
    },
    {
        "video": "tutorial_python_basico.mp4",
        "mail": "usuario_python@email.com",
    },
    {
        "video": "viaje_espacial_turismo.mp4",
        "mail": "entusiasta_espacio@email.com",
    },
    {
        "video": "documental_historia_arte.mp4",
        "mail": "arte_historia@email.com",
    },
    {
        "video": "ejercicios_yoga_principiantes.mp4",
        "mail": "yoga_novato@email.com",
    },
    {
        "video": "recetas_saludables_faciles.mp4",
        "mail": "cocinero_saludable@email.com",
    },
    {
        "video": "economia_basica_para_novatos.mp4",
        "mail": "novato_economia@email.com",
    },
    {
        "video": "aprendiendo_ajedrez_desde_cero.mp4",
        "mail": "ajedrez_novato@email.com",
    },
    {
        "video": "meditacion_guiada_30_minutos.mp4",
        "mail": "meditacion_practicante@email.com",
    },
    {
        "video": "tutorial_jardineria_basico.mp4",
        "mail": "jardinero_principiante@email.com",
    },
    {
        "video": "clases_de_frances_intermedio.mp4",
        "mail": "aprendiz_frances@email.com",
    }
]
